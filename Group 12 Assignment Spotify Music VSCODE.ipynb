# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Group Assignment Big Data/spotify_data.csv')

# %%
dtype_mapping = {
    "artist_name": "string",
    "track_name": "string",
    "track_id": "string",
    "popularity": "int",
    "year": "int",
    "genre": "string",
    "danceability": "float",
    "energy": "float",
    "key": "int",
    "loudness": "float",
    "mode": "int",
    "speechiness": "float",
    "acousticness": "float",
    "instrumentalness": "float",
    "liveness": "float",
    "valence": "float",
    "tempo": "float",
    "duration_ms": "float",
    "time_signature": "int"
}

df = df.astype(dtype_mapping)

# %%
print(df.head(5))
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    duration_ms  time_signature
# 0     240166.0               3
# 1     216387.0               4
# 2     158960.0               4
# 3     304293.0               4
# 4     244320.0               4

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Unnamed: 0', 'artist_name', 'track_name', 'track_id', 'popularity', 'year', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159764 non-null  string
#  2   track_name        1159764 non-null  string
#  3   track_id          1159764 non-null  string
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  string
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
#  15  liveness          1159764 non-null  float64
#  16  valence           1159764 non-null  float64
#  17  tempo             1159764 non-null  float64
#  18  duration_ms       1159764 non-null  float64
#  19  time_signature    1159764 non-null  int64
# dtypes: float64(10), int64(6), string(4)
# memory usage: 177.0 MB

# %%
# Cast the columns
df = df.astype(dtype_mapping)

# Print the DataFrame's information to check the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159764 non-null  string
#  2   track_name        1159764 non-null  string
#  3   track_id          1159764 non-null  string
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  string
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
#  15  liveness          1159764 non-null  float64
#  16  valence           1159764 non-null  float64
#  17  tempo             1159764 non-null  float64
#  18  duration_ms       1159764 non-null  float64
#  19  time_signature    1159764 non-null  int64
# dtypes: float64(10), int64(6), string(4)
# memory usage: 177.0 MB

# %%
# Get unique values from the 'genre' column
genreRows = df['genre'].unique()

# Print the unique genre values
print(genreRows)
# Out:
# <StringArray>
# [         'acoustic',          'afrobeat',          'alt-rock',
#            'ambient',       'black-metal',             'blues',
#          'breakbeat',          'cantopop',     'chicago-house',
#              'chill',         'classical',              'club',
#             'comedy',           'country',             'dance',
#          'dancehall',       'death-metal',        'deep-house',
#     'detroit-techno',             'disco',     'drum-and-bass',
#                'dub',           'dubstep',               'edm',
#            'electro',        'electronic',               'emo',
#               'folk',             'forro',            'french',
#               'funk',            'garage',            'german',
#             'gospel',              'goth',         'grindcore',
#             'groove',            'guitar',         'hard-rock',
#           'hardcore',         'hardstyle',       'heavy-metal',
#            'hip-hop',             'house',            'indian',
#          'indie-pop',        'industrial',              'jazz',
#              'k-pop',             'metal',         'metalcore',
#     'minimal-techno',           'new-age',             'opera',
#              'party',             'piano',               'pop',
#           'pop-film',         'power-pop', 'progressive-house',
#         'psych-rock',              'punk',         'punk-rock',
#               'rock',       'rock-n-roll',           'romance',
#                'sad',             'salsa',             'samba',
#          'sertanejo',        'show-tunes', 'singer-songwriter',
#                'ska',             'sleep',        'songwriter',
#               'soul',           'spanish',           'swedish',
#              'tango',            'techno',            'trance',
#           'trip-hop']
# Length: 82, dtype: string

# %%
# Group by 'genre' and count the occurrences
genre_counts = df.groupby('genre').size()

# Display the result
print(genre_counts)
# Out:
# genre
# acoustic       21097
# afrobeat       12395
# alt-rock       20918
# ambient        21389
# black-metal    21852
#                ...
# swedish        11616
# tango          15069
# techno          7898
# trance          9592
# trip-hop       11285
# Length: 82, dtype: int64

# %%
total_rows = df.shape[0]
print("Total rows:", total_rows)
# Out:
# Total rows: 1159764

# %%
# Iterate over each column and print rows where the column value is null
for column in df.columns:
    print('Analyzing', column)
    null_rows = df[df[column].isna()]
    print(null_rows)
# Out:
# Analyzing Unnamed: 0
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing artist_name
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing track_name
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing track_id
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing popularity
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing year
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing genre
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing danceability
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing energy
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing key
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing loudness
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing mode
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing speechiness
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing acousticness
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing instrumentalness
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing liveness
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing valence
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing tempo
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing duration_ms
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []
# Analyzing time_signature
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# year                0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
# Group by 'track_name' and 'artist_name', and count occurrences
track_artist_counts = df.groupby(['track_name', 'artist_name']).size().reset_index(name='count')

# Filter for counts greater than one
repeated_tracks_artists = track_artist_counts[track_artist_counts['count'] > 1]

# Display the result
print(repeated_tracks_artists)
# Out:
# Empty DataFrame
# Columns: [track_name, artist_name, count]
# Index: []

# %%
# Drop duplicates based on 'artist_name' and 'track_name'
df_unique = df.drop_duplicates(subset=['artist_name', 'track_name'])

# Display the first few rows of the resulting DataFrame
print(df_unique.head())
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    duration_ms  time_signature
# 0     240166.0               3
# 1     216387.0               4
# 2     158960.0               4
# 3     304293.0               4
# 4     244320.0               4

# %%
def iqr_outlier_treatment(dataframe, columns, factor=1.5):
    """
    Detects and treats outliers using IQR for multiple variables in a Pandas DataFrame.

    :param dataframe: The input Pandas DataFrame
    :param columns: A list of columns to apply IQR outlier treatment
    :param factor: The IQR factor to use for detecting outliers (default is 1.5)
    :return: The processed DataFrame with outliers treated
    """
    for column in columns:
        # Calculate Q1 and Q3
        q1 = dataframe[column].quantile(0.25)
        q3 = dataframe[column].quantile(0.75)
        iqr = q3 - q1

        # Define the upper and lower bounds for outliers
        lower_bound = q1 - factor * iqr
        upper_bound = q3 + factor * iqr

        # Filter out the outliers
        dataframe = dataframe[(dataframe[column] >= lower_bound) & (dataframe[column] <= upper_bound)]

    return dataframe

# %%
# Filter out rows where 'tempo' equals 0
df_filtered = df[df['tempo'] > 0]

# Calculate the quartiles and IQR
bounds = df_filtered['tempo'].quantile([0.25, 0.75])
IQR = bounds[0.75] - bounds[0.25]
lower_bound = bounds[0.25] - 1.5 * IQR
upper_bound = bounds[0.75] + 1.5 * IQR

# Remove outliers
df_no_outliers = df_filtered[(df_filtered['tempo'] >= lower_bound) & (df_filtered['tempo'] <= upper_bound)]

# Calculate percentile rank
df_no_outliers['percentile_rank'] = df_no_outliers['tempo'].rank(pct=True)

# Function to categorize based on quartiles
def categorize_tempo(x):
    if x < 0.25:
        return 'G1'
    elif x < 0.5:
        return 'G2'
    elif x < 0.75:
        return 'G3'
    else:
        return 'G4'

# Assign tempo group
df_no_outliers['tempo_group'] = df_no_outliers['percentile_rank'].apply(categorize_tempo)

# Display the results
print(df_no_outliers.head())
# Out:
# <ipython-input-16-bf487be0a723>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['percentile_rank'] = df_no_outliers['tempo'].rank(pct=True)
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
# 5           5  Chris Smither     What They Say  24NvptbNKGs6sPy1Vh1O0v
#
#    popularity  year     genre  danceability  energy  key  ...  speechiness  \
# 0          68  2012  acoustic         0.483   0.303    4  ...       0.0429
# 1          50  2012  acoustic         0.572   0.454    3  ...       0.0258
# 2          57  2012  acoustic         0.409   0.234    3  ...       0.0323
# 4          54  2012  acoustic         0.430   0.791    6  ...       0.0302
# 5          48  2012  acoustic         0.566   0.570    2  ...       0.0329
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.6940          0.000000    0.1150    0.139  133.406     240166.0
# 1        0.4770          0.000014    0.0974    0.515  140.182     216387.0
# 2        0.3380          0.000050    0.0895    0.145  139.832     158960.0
# 4        0.0726          0.019300    0.1100    0.217  171.864     244320.0
# 5        0.6880          0.000002    0.0943    0.960   83.403     166240.0
#
#    time_signature  percentile_rank  tempo_group
# 0               3         0.686693           G3
# 1               4         0.772102           G4
# 2               4         0.750951           G4
# 4               4         0.933780           G4
# 5               4         0.104040           G1
#
# [5 rows x 22 columns]
# <ipython-input-16-bf487be0a723>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['tempo_group'] = df_no_outliers['percentile_rank'].apply(categorize_tempo)

# %%
integerColumns = ["popularity", "year", "key", "mode", "duration_ms", "time_signature"]
floatColumns = ["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

print("Integer Columns:", integerColumns)
print("Float Columns:", floatColumns)
# Out:
# Integer Columns: ['popularity', 'year', 'key', 'mode', 'duration_ms', 'time_signature']
# Float Columns: ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
numeric_columns = integerColumns + floatColumns

# Displaying the combined list
print("Numeric Columns:", numeric_columns)
# Out:
# Numeric Columns: ['popularity', 'year', 'key', 'mode', 'duration_ms', 'time_signature', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
df_outlier_treatment = iqr_outlier_treatment(df, numeric_columns, factor=1.5)

# %%
# Joining the original DataFrame with the outlier-treated DataFrame
# Assuming df and df_outlier_treatment are Pandas DataFrames
outliers_df = df.join(df_outlier_treatment[numeric_columns], rsuffix="_treated")

# %%
import matplotlib.pyplot as plt

for column in numeric_columns:
  treated = column + "_treated"
  print("Outliers for ", column)
  plt.figure()
  outliers_df.boxplot(column= [column, treated], grid=False, figsize=(6,3))
  plt.show()
# Out:
# Outliers for  popularity
# Outliers for  year
# Outliers for  key
# Outliers for  mode
# Outliers for  duration_ms
# Outliers for  time_signature
# Outliers for  danceability
# Outliers for  energy
# Outliers for  loudness
# Outliers for  speechiness
# Outliers for  acousticness
# Outliers for  instrumentalness
# Outliers for  liveness
# Outliers for  valence
# Outliers for  tempo

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Define your string columns
stringColumns = ['artist_name', 'track_name', 'track_id', 'genre']

# Drop non-numeric columns
numeric_df = df.drop(columns=stringColumns)

# Compute the correlation matrix
corr_mat_df = numeric_df.corr(method='pearson')

# Visualize the correlation matrix
plt.figure(figsize=(16, 5))
sns.heatmap(corr_mat_df, xticklabels=corr_mat_df.columns, yticklabels=corr_mat_df.columns, cmap="Greens", annot=True)
plt.show()

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Assuming df is your DataFrame

# Further sample the data if necessary
sampled_df = df.sample(frac=0.95, random_state=42)  # Adjust the fraction as needed

# Preprocessing: Label encode genres and normalize tempo
label_encoder = LabelEncoder()
genres_encoded = label_encoder.fit_transform(sampled_df['genre']).reshape(-1, 1)
scaler = MinMaxScaler()
tempo_normalized = scaler.fit_transform(sampled_df[['tempo']])

# Combine features without one-hot encoding
features = np.hstack((genres_encoded, tempo_normalized))

# Simplify the recommendation by using a basic similarity metric
# For example, using Euclidean distance
from scipy.spatial.distance import cdist

def recommend_songs(song_index, top_n=10):
    distances = cdist([features[song_index]], features, 'euclidean')
    top_indices = np.argsort(distances[0])[:top_n]
    return sampled_df.iloc[top_indices]

# Example usage
recommended_songs = recommend_songs(0, top_n=5)
